# %%
## Read a whole file
with open('example.txt', 'r') as file:
    content =file.read()
    print(content)
# Out:
# Hello How Are You!!
# And I am Good

# %%
# Read a file line by line
with open('example.txt' , 'r') as file:
    for line in file:
        print(line.strip()) # Strip() removes the newline character
# Out:
# Hello How Are You!!
# And I am Good

# %%
# Writing a file ==> open
with open('example.txt' , 'w') as file: # W is the write mode
    file.write("Hello Wolrd\n")
    file.write("This is a new line.")

# %%
# Write a file withour overwriting
with open('example.txt' ,'a') as file:
    file.write("Append operation taking place?\n")

# %%
# Wrting a list of lines in a file

lines = ["First Line\n" , "Second Line\n" , "Third Line\n"]
with open('example.txt' , 'a') as file:
    file.writelines(lines)

# %%
# Binary Files
