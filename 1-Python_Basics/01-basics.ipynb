# %% [markdown]
# ## Python Basics
# ##### IPYKERNEL IS RESPONSIBLE TO EXECUTE THE PYTHON CODE

# %%
print("Hello")
# Out:
# Hello

# %%
## Basic rules in python
# Python is case sensitive
## (DOUBLE HASH)==> It is used to comment single line comment
# For multi line comment we will use tripple quotes
'''EXAMPLE OF TRIPLE QUOTES'''
# Out:
# 'EXAMPLE OF TRIPLE QUOTES'

# %%
name = "Ozan"
print(name)
Name = "Effendi"
print(Name)
## This means that python is case sensitive
# Out:
# Ozan
# Effendi
# Ozan

# %%
## INTENDATION
## Python uses intendation to define blocks of code ==> Defining strudture and heirarchy of the code

# %%
# EG:: 
for i in range(4):
    print("Hello") # This is the intendation
# Out:
# Hello
# Hello
# Hello
# Hello

# %%
for j in "HEllO":
    print(j) # This is the intendation
# Out:
# H
# E
# l
# l
# O

# %%
age = 18
if age >= 18:
    print("You are eligible to vote")
else:
    print("You are not eligible to vote")
# Out:
# You are eligible to vote

# %%
total = 12+12+12+\
4+5+6+7+8+9+10
print(total)
#Using backslash to continue the line
# Out:
# 85

# %%
x=1
y=2
z= x+y
print(z)
# Simple addition of two numbers
# Output will be 3
x = "Hello "
y = "World"
z = x + y
print(z)
# Simple concatenation of two strings   
# Output will be Hello World
# Out:
# 3
# Hello World

# %%
age = 25
name = "Ozan"
print(type(age))
print(type(name))
# Out:
# <class 'int'>
# <class 'str'>
