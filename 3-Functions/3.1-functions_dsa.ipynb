# %%
## Functions
# A Function is a block of code that performs a specific task..==> Hlep in organizing the code

# %%
#Syntax
def function_name(parameters):
    return("Hello")

# %%
def add(x,y): ## This is a addition function..
    """Docstring"""
    return x+y
add(1,2)
# Out:
# 3

# %%
def celsius_to_fahrenheit(C):
    """
    Function to convert temperature from Celsius to Fahrenheit.
    
    Parameters:
    C (float): The temperature in Celsius.
    
    Returns:
    float: The temperature in Fahrenheit.
    """
    F = (9/5 * C) + 32
    return F

celsius_to_fahrenheit(25)
# Out:
# 77.0

# %%
def area_of_rectangle(length, breadth):
    """
    Function to calculate the area of a rectangle.
    
    Parameters:
    length (float): The length of the rectangle.
    breadth (float): The breadth of the rectangle.
    
    Returns:
    float: The area of the rectangle.
    """
    # Your code here
    area = length*breadth
    return area

area_of_rectangle(2,4)
# Out:
# 8

# %%
def calculate_lift_rounds(n, capacity):
    """
    Function to calculate the number of rounds the lift needs to cover.
    
    Parameters:
    n (int): Total number of people.
    capacity (int): Maximum number of people the lift can carry in one round.
    
    Returns:
    int: The number of rounds required to transport al
    
    l people to the top floor.
    """
    # Your code here
    import math
    rounds = math.ceil(n/capacity)
    return rounds

calculate_lift_rounds(10,2)
# Out:
# 5

# %%
def calculate_y(slope, intercept, x):
    """
    Function to calculate the value of y using the slope-intercept form of a line.
    
    Parameters:
    slope (float): The slope of the line.
    intercept (float): The y-intercept of the line.
    x (float): The value of x for which y needs to be calculated.
    
    Returns:
    float: The calculated v
    alue of y.
    m == slope
    x == independent variable
    y == dependent variable
    """
    y = slope * x + intercept
    return float(y)

calculate_y(2,3,4)
# Out:
# 11.0

# %%
def sum_list(numbers):
    total = 0
    for i in numbers:
        total += i
    return total

print(sum_list([1,2,3,4,5]))
# Out:
# 15

# %%
def find_largest(numbers):
    largest = numbers[0]
    for i in numbers:
        if i > largest:
            largest = i
    return largest
    pass
find_largest([1,2,3,4,5,6,9,0,10,21,31])
# Out:
# 31

# %%
num = [1,4,6,11,19,10]
largest = num[0]
for i in num:
    if i > largest:
        largest = i
print(largest)
# Out:
# 19

# %%
def remove_duplicates(lst):
    unique = []
    for i in lst:
        if i not in unique:
            unique.append(i)
    return unique
    pass
remove_duplicates([1,2,2,2,3,4])
# Out:
# [1, 2, 3, 4]

# %%
lst = [1,2,3,4,4,5]
unique = []
for i in lst:
    if i not in unique:
        unique.append(i)
print(unique)
# Out:
# [1, 2, 3, 4, 5]

# %%
def check_unique(lst):
    seen = []
    for i in lst:
        if i in seen:
            return False
            break
        seen.append(i)
    else:
        return True
    pass
check_unique([1,2,3,2,5])
# Out:
# False

# %%
lst = [1,2,3,4,5]
seen = []
for i in lst:
    if i in seen:
        print(False)
        break
    seen.append(i)
else:
    print(True)
# Out:
# True

# %%
def reverse_list(lst):
    lst.reverse()
    return lst
    pass

# %%
lst = [1,2,3,4]
lst.reverse()
print(lst)
# Out:
# [4, 3, 2, 1]

# %%
def count_even_odd(lst):
    oddcount = 0
    evencount = 0
    for i in lst:
        if i %2 == 0:
            evencount = evencount +1
        elif i %2 == 1:
            oddcount = oddcount +1
    return (evencount , oddcount)
    pass
count_even_odd([1,2,3,4,5])
# Out:
# (2, 3)

# %%
lst = [1, 2, 3, 4, 5]
oddcount = 0
evencount = 0
for i in lst:
    if i%2==0:
        evencount = evencount+1
    elif i%2==1:
        oddcount = oddcount +1
print((evencount,oddcount))
# Out:
# (2, 3)

# %%
def is_subset(lst1, lst2):
    if set(lst2).issubset(set(lst1)) or set(lst1).issubset(set(lst2)):
        return True
    else:
        return False
    pass

# %%
lst1 = [1,2,3,4,5]
lst2 = [1,2,3]
if set(lst2).issubset(set(lst1)):
    print(True)
else:
    print(False)
# Out:
# True

# %%
def subtraction(num1, num2):
    return abs(num1 - num2)


def max_consecutive_difference(lst):
    max_diff = 0
    
    for i in range(len(lst) - 1):
        difference = subtraction(lst[i], lst[i + 1])
        
        if difference > max_diff:
            max_diff = difference
    
    return max_diff

# %%
max_diff = 0
lst = [1, 7, 3, 10, 5]
for i in range(len(lst) -1):
    difference = subtraction(lst[i], lst[i + 1])
    if difference > max_diff:
        max_diff = difference

print(max_diff)

def subtraction(num1, num2):
    return abs(num1 - num2)
# Out:
# 7

# %%
def merge_two_sorted_lists(list1, list2):
    i = 0
    j = 0
    merged = []
    
    while i < len(list1) and j < len(list2):
        if list1[i] < list2[j]:
            merged.append(list1[i])
            i += 1
        else:
            merged.append(list2[j])
            j += 1
    
    while i < len(list1):
        merged.append(list1[i])
        i += 1
        
    while j < len(list2):
        merged.append(list2[j])
        j += 1
    
    return merged
