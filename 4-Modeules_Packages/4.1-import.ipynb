# %%
import math
x = math.sqrt(16)
print(x)
# Out:
# 4.0

# %%
from math import sqrt, pi
print(pi)
print(sqrt(25))
# Out:
# 3.141592653589793
# 5.0

# %%
import numpy as np
np.array([1,2,34,5,6])
# Out:
# array([ 1,  2, 34,  5,  6])

# %%
from math import *  ## Importing all of the functions available in maths
sqrt(10)
# etc
# Out:
# 3.1622776601683795

# %%
from package.maths import addition
addition(2,4)
# Out:
# 6

# %%
from package.maths import *
subtraction(5,3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 2
#       1 from package.maths import *
# ----> 2 subtraction(5,3)
#
# NameError: name 'subtraction' is not defined
