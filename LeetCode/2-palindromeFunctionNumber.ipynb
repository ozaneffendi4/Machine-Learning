# %%
class Solution(object):
    def isPalindrome(x):
        """
        :type x: int
        :rtype: bool
        """
        positive = abs(x)
        reversed_int = int(str(positive)[::-1])
        if x == reversed_int:
            return True
        else:
            return False

Solution.isPalindrome(121)
# Out:
# True

# %%
# Out:
# True
